# %%
import numpy as np # for numerical computation
import pandas as pd # for data analysis and manipulation
import os # for reading filenames from directory
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/electric-power-consumption-data-set/household_power_consumption.txt

# %%
# Reading the file path into a pandas Dataframe and viewing it
df = pd.read_csv("/kaggle/input/electric-power-consumption-data-set/household_power_consumption.txt", parse_dates=[['Date', 'Time']], delimiter=';', 
                na_values=['nan','?'])
df.head()

# %%
df.dtypes

# %% [markdown]
# **Data Preprocessing**

# %%
# To check the number of rows and columns (shape) of the dataset in the DataFrame
df.shape

# %%
# To get information about the dataset
df.info()

# %%
# To check for missing values
df.isnull().sum()

# %%
df = df.set_index('Date_Time')
df.head()

# %%
# We use Backfill to replace the missing data in the dataset
for NaN in range(0,7):        
        df.iloc[:,NaN] = df.iloc[:,NaN].fillna(df.iloc[:,NaN].bfill())

# %%
# We verify again to ensure there are no more missing data
df.isnull().sum()
